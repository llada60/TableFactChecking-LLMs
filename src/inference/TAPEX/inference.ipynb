# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import pandas as pd
import torch
import json

# %%
tokenizer = AutoTokenizer.from_pretrained(
    "microsoft/tapex-large-finetuned-tabfact"
)
model = AutoModelForSequenceClassification.from_pretrained(
    "microsoft/tapex-large-finetuned-tabfact"
)
model.eval()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# You passed `num_labels=3` which is incompatible to the `id2label` map of length `2`.
# pytorch_model.bin:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# BartForSequenceClassification(
#   (model): BartModel(
#     (shared): BartScaledWordEmbedding(50265, 1024, padding_idx=1)
#     (encoder): BartEncoder(
#       (embed_tokens): BartScaledWordEmbedding(50265, 1024, padding_idx=1)
#       (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#       (layers): ModuleList(
#         (0-11): 12 x BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): BartDecoder(
#       (embed_tokens): BartScaledWordEmbedding(50265, 1024, padding_idx=1)
#       (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#       (layers): ModuleList(
#         (0-11): 12 x BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (classification_head): BartClassificationHead(
#     (dense): Linear(in_features=1024, out_features=1024, bias=True)
#     (dropout): Dropout(p=0.0, inplace=False)
#     (out_proj): Linear(in_features=1024, out_features=2, bias=True)
#   )
# )

# %%
print(model.config.id2label)
# Out:
# {0: 'Refused', 1: 'Entailed'}

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

model.to(device)
# Out:
# Using device: cuda
# BartForSequenceClassification(
#   (model): BartModel(
#     (shared): BartScaledWordEmbedding(50265, 1024, padding_idx=1)
#     (encoder): BartEncoder(
#       (embed_tokens): BartScaledWordEmbedding(50265, 1024, padding_idx=1)
#       (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#       (layers): ModuleList(
#         (0-11): 12 x BartEncoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): BartDecoder(
#       (embed_tokens): BartScaledWordEmbedding(50265, 1024, padding_idx=1)
#       (embed_positions): BartLearnedPositionalEmbedding(1026, 1024)
#       (layers): ModuleList(
#         (0-11): 12 x BartDecoderLayer(
#           (self_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (activation_fn): GELUActivation()
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): BartAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layernorm_embedding): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (classification_head): BartClassificationHead(
#     (dense): Linear(in_features=1024, out_features=1024, bias=True)
#     (dropout): Dropout(p=0.0, inplace=False)
#     (out_proj): Linear(in_features=1024, out_features=2, bias=True)
#   )
# )

# %%
def table_str_to_df(table_str):
    rows = [r.split("#") for r in table_str.strip().split("\n")]
    header, data = rows[0], rows[1:]
    return pd.DataFrame(data, columns=header)

def tapex_predict(table_str, statement):
    table_df = table_str_to_df(table_str)

    encoding = tokenizer(
        table=table_df,
        query=statement,
        return_tensors="pt",
        truncation=True
    )

    encoding = {k: v.to(device) for k, v in encoding.items()}

    with torch.no_grad():
        outputs = model(**encoding)

    pred_idx = outputs.logits.argmax(dim=-1).item()
    pred_label = model.config.id2label[pred_idx]

    return 1 if pred_label == "Entailed" else 0

# %%
adversarial_dataset_path = "/content/test_examples_with_csv_adversarial_flattened.json"
dataset_path = "/content/test_examples_with_csv_flattened.json"
paraphrased_dataset_path = "/content/test_examples_with_csv_paraphrased_flattened.json"

dataset_paths = {'original': dataset_path, 'adversarial': adversarial_dataset_path, 'paraphrased': paraphrased_dataset_path}

max_runs = -1 # -1 to run all

# %%
results = {'original': {}, 'adversarial': {}, 'paraphrased': {}}

# %%
for mode, path in dataset_paths.items():

  dataset = json.load(open(path))

  correct = 0
  total = 0

  n=0

  for ex in dataset:
      if n==max_runs:
          break
      n+=1
      pred = tapex_predict(ex["table"], ex["statement"])
      gold = ex["label"]

      # print(f"Statement: {ex['statement']}")
      # print(f"Predicted: {pred}, Gold: {gold}\n")

      correct += (pred == gold)
      total += 1

      if n%100==0:
        print(f"Mode: {mode}, Done: {n}/{len(dataset)}")

      if n%1000==0:
        print(f"Accuracy: {correct/total*100:.2f}%")

  results[mode]["correct"] = correct
  results[mode]["total"] = total
  results[mode]["accuracy"] = correct/total*100

  print(f"Mode: {mode}, Final Accuracy: {correct/total*100:.2f}%")
# Mode: original, Done: 8700/12779
# Mode: original, Done: 8800/12779
# Mode: original, Done: 8900/12779
# Mode: original, Done: 9000/12779
# Accuracy: 79.10%
# Mode: original, Done: 9100/12779
# Mode: original, Done: 9200/12779
# Mode: original, Done: 9300/12779
# Mode: original, Done: 9400/12779
# Mode: original, Done: 9500/12779
# Mode: original, Done: 9600/12779
# Mode: original, Done: 9700/12779
# Mode: original, Done: 9800/12779
# Mode: original, Done: 9900/12779
# Mode: original, Done: 10000/12779
# Accuracy: 80.50%
# Mode: original, Done: 10100/12779
# Mode: original, Done: 10200/12779
# Mode: original, Done: 10300/12779
# Mode: original, Done: 10400/12779
# Mode: original, Done: 10500/12779
# Mode: original, Done: 10600/12779
# Mode: original, Done: 10700/12779
# Mode: original, Done: 10800/12779
# Mode: original, Done: 10900/12779
# Mode: original, Done: 11000/12779
# Accuracy: 81.70%
# Mode: original, Done: 11100/12779
# Mode: original, Done: 11200/12779
# Mode: original, Done: 11300/12779
# Mode: original, Done: 11400/12779
# Mode: original, Done: 11500/12779
# Mode: original, Done: 11600/12779
# Mode: original, Done: 11700/12779
# Mode: original, Done: 11800/12779
# Mode: original, Done: 11900/12779
# Mode: original, Done: 12000/12779
# Accuracy: 82.70%
# Mode: original, Done: 12100/12779
# Mode: original, Done: 12200/12779
# Mode: original, Done: 12300/12779
# Mode: original, Done: 12400/12779
# Mode: original, Done: 12500/12779
# Mode: original, Done: 12600/12779
# Mode: original, Done: 12700/12779
# Mode: original, Final Accuracy: 83.43%
# Mode: adversarial, Done: 100/10928
# Mode: adversarial, Done: 200/10928
# Mode: adversarial, Done: 300/10928
# Mode: adversarial, Done: 400/10928
# Mode: adversarial, Done: 500/10928
# Mode: adversarial, Done: 600/10928
# Mode: adversarial, Done: 700/10928
# Mode: adversarial, Done: 800/10928
# Mode: adversarial, Done: 900/10928
# Mode: adversarial, Done: 1000/10928
# Accuracy: 57.50%
# Mode: adversarial, Done: 1100/10928
# Mode: adversarial, Done: 1200/10928
# Mode: adversarial, Done: 1300/10928
# Mode: adversarial, Done: 1400/10928
# Mode: adversarial, Done: 1500/10928
# Mode: adversarial, Done: 1600/10928
# Mode: adversarial, Done: 1700/10928
# Mode: adversarial, Done: 1800/10928
# Mode: adversarial, Done: 1900/10928
# Mode: adversarial, Done: 2000/10928
# Accuracy: 57.70%
# Mode: adversarial, Done: 2100/10928
# Mode: adversarial, Done: 2200/10928
# Mode: adversarial, Done: 2300/10928
# Mode: adversarial, Done: 2400/10928
# Mode: adversarial, Done: 2500/10928
# Mode: adversarial, Done: 2600/10928
# Mode: adversarial, Done: 2700/10928
# Mode: adversarial, Done: 2800/10928
# Mode: adversarial, Done: 2900/10928
# Mode: adversarial, Done: 3000/10928
# Accuracy: 57.97%
# Mode: adversarial, Done: 3100/10928
# Mode: adversarial, Done: 3200/10928
# Mode: adversarial, Done: 3300/10928
# Mode: adversarial, Done: 3400/10928
# Mode: adversarial, Done: 3500/10928
# Mode: adversarial, Done: 3600/10928
# Mode: adversarial, Done: 3700/10928
# Mode: adversarial, Done: 3800/10928
# Mode: adversarial, Done: 3900/10928
# Mode: adversarial, Done: 4000/10928
# Accuracy: 58.45%
# Mode: adversarial, Done: 4100/10928
# Mode: adversarial, Done: 4200/10928
# Mode: adversarial, Done: 4300/10928
# Mode: adversarial, Done: 4400/10928
# Mode: adversarial, Done: 4500/10928
# Mode: adversarial, Done: 4600/10928
# Mode: adversarial, Done: 4700/10928
# Mode: adversarial, Done: 4800/10928
# Mode: adversarial, Done: 4900/10928
# Mode: adversarial, Done: 5000/10928
# Accuracy: 58.58%
# Mode: adversarial, Done: 5100/10928
# Mode: adversarial, Done: 5200/10928
# Mode: adversarial, Done: 5300/10928
# Mode: adversarial, Done: 5400/10928
# Mode: adversarial, Done: 5500/10928
# Mode: adversarial, Done: 5600/10928
# Mode: adversarial, Done: 5700/10928
# Mode: adversarial, Done: 5800/10928
# Mode: adversarial, Done: 5900/10928
# Mode: adversarial, Done: 6000/10928
# Accuracy: 58.47%
# Mode: adversarial, Done: 6100/10928
# Mode: adversarial, Done: 6200/10928
# Mode: adversarial, Done: 6300/10928
# Mode: adversarial, Done: 6400/10928
# Mode: adversarial, Done: 6500/10928
# Mode: adversarial, Done: 6600/10928
# Mode: adversarial, Done: 6700/10928
# Mode: adversarial, Done: 6800/10928
# Mode: adversarial, Done: 6900/10928
# Mode: adversarial, Done: 7000/10928
# Accuracy: 58.87%
# Mode: adversarial, Done: 7100/10928
# Mode: adversarial, Done: 7200/10928
# Mode: adversarial, Done: 7300/10928
# Mode: adversarial, Done: 7400/10928
# Mode: adversarial, Done: 7500/10928
# Mode: adversarial, Done: 7600/10928
# Mode: adversarial, Done: 7700/10928
# Mode: adversarial, Done: 7800/10928
# Mode: adversarial, Done: 7900/10928
# Mode: adversarial, Done: 8000/10928
# Accuracy: 59.55%
# Mode: adversarial, Done: 8100/10928
# Mode: adversarial, Done: 8200/10928
# Mode: adversarial, Done: 8300/10928
# Mode: adversarial, Done: 8400/10928
# Mode: adversarial, Done: 8500/10928
# Mode: adversarial, Done: 8600/10928
# Mode: adversarial, Done: 8700/10928
# Mode: adversarial, Done: 8800/10928
# Mode: adversarial, Done: 8900/10928
# Mode: adversarial, Done: 9000/10928
# Accuracy: 59.81%
# Mode: adversarial, Done: 9100/10928
# Mode: adversarial, Done: 9200/10928
# Mode: adversarial, Done: 9300/10928
# Mode: adversarial, Done: 9400/10928
# Mode: adversarial, Done: 9500/10928
# Mode: adversarial, Done: 9600/10928
# Mode: adversarial, Done: 9700/10928
# Mode: adversarial, Done: 9800/10928
# Mode: adversarial, Done: 9900/10928
# Mode: adversarial, Done: 10000/10928
# Accuracy: 60.10%
# Mode: adversarial, Done: 10100/10928
# Mode: adversarial, Done: 10200/10928
# Mode: adversarial, Done: 10300/10928
# Mode: adversarial, Done: 10400/10928
# Mode: adversarial, Done: 10500/10928
# Mode: adversarial, Done: 10600/10928
# Mode: adversarial, Done: 10700/10928
# Mode: adversarial, Done: 10800/10928
# Mode: adversarial, Done: 10900/10928
# Mode: adversarial, Final Accuracy: 60.53%
# Mode: paraphrased, Done: 100/12779
